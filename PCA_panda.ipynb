# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.style.use('ggplot')

# %%
plt.style.use('ggplot')
df = pd.read_csv('...../Python/DAT210x-master/Module3/Datasets/wheat.data')

# %%
df
# Out:
#       id   area  perimeter  compactness  length  width  asymmetry  groove  \
# 0      0  15.26      14.84       0.8710   5.763  3.312     2.2210   5.220
# 1      1  14.88      14.57       0.8811   5.554  3.333     1.0180   4.956
# 2      2  14.29      14.09       0.9050   5.291  3.337     2.6990   4.825
# 3      3  13.84      13.94       0.8955   5.324  3.379     2.2590   4.805
# 4      4  16.14      14.99       0.9034   5.658  3.562     1.3550   5.175
# 5      5  14.38      14.21       0.8951   5.386  3.312     2.4620   4.956
# 6      6  14.69      14.49       0.8799   5.563  3.259     3.5860   5.219
# 7      7  14.11      14.10       0.8911   5.420  3.302     2.7000     NaN
# 8      8  16.63      15.46       0.8747   6.053  3.465     2.0400   5.877
# 9      9  16.44      15.25       0.8880   5.884  3.505     1.9690   5.533
# 10    10  15.26      14.85       0.8696   5.714  3.242     4.5430   5.314
# 11    11  14.03      14.16       0.8796   5.438  3.201     1.7170   5.001
# ...

# %%
s1 = df.loc[:, 'area':'perimeter']
s1
# Out:
#       area  perimeter
# 0    15.26      14.84
# 1    14.88      14.57
# 2    14.29      14.09
# 3    13.84      13.94
# 4    16.14      14.99
# 5    14.38      14.21
# 6    14.69      14.49
# 7    14.11      14.10
# 8    16.63      15.46
# 9    16.44      15.25
# 10   15.26      14.85
# 11   14.03      14.16
# 12   13.89      14.02
# 13   13.78      14.06
# 14   13.74      14.05
# 15   14.59      14.28
# 16   13.99      13.83
# 17   15.69      14.75
# 18   14.70      14.21
# 19   12.72      13.57
# 20   14.16      14.40
# 21   14.11      14.26
# 22   15.88      14.90
# 23   12.08      13.23
# 24   15.01      14.76
# 25   16.19      15.16
# 26   13.02      13.76
# 27   12.74      13.67
# 28   14.11      14.18
# 29   13.45      14.02
# ..     ...        ...
# 180  11.41      12.95
# 181  12.46      13.41
# 182  12.19      13.36
# 183  11.65      13.07
# 184  12.89      13.77
# 185  11.56      13.31
# 186  11.81      13.45
# 187  10.91      12.80
# 188  11.23      12.82
# ...

# %%
s2 = df.loc[:,'asymmetry':'groove']
s2
# Out:
#      asymmetry  groove
# 0       2.2210   5.220
# 1       1.0180   4.956
# 2       2.6990   4.825
# 3       2.2590   4.805
# 4       1.3550   5.175
# 5       2.4620   4.956
# 6       3.5860   5.219
# 7       2.7000     NaN
# 8       2.0400   5.877
# 9       1.9690   5.533
# 10      4.5430   5.314
# 11      1.7170   5.001
# 12      3.9860   4.738
# 13      3.1360   4.872
# 14      2.9320   4.825
# 15      4.1850   4.781
# 16      5.2340   4.781
# 17      1.5990   5.046
# 18      1.7670   4.649
# 19      4.1020   4.914
# 20      3.0720   5.176
# 21      2.6880   5.219
# 22      0.7651   5.091
# 23      1.4150   4.961
# 24      1.7910   5.001
# 25      0.9030   5.307
# 26      3.3730   4.825
# 27      2.5040   4.869
# 28      2.7540   5.038
# 29      3.5310   5.097
# ..         ...     ...
# 180     4.9570   4.825
# 181     4.9870   5.147
# 182     4.8570   5.158
# 183     5.2090   5.135
# 184     6.1850   5.316
# 185     4.0620   5.182
# 186     4.8980   5.352
# 187     4.1790   4.956
# ...

# %%
s1.plot.hist(alpha=0.5)
plt.show()

# %%
s1.plot.hist(alpha=0.75)

# %%
plt.show()

# %%
s2.plot.hist(alpha=0.75)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
from plyfile import PlyData, PlyElement
plt.style.use('ggplot')

# %%
plyfile=PlyData.read('....../DAT210x-master/Module4/Datasets/stanford_armadillo.ply')

# %%
reduce_factor = 100
armadillo = pd.DataFrame({'x':plyfile['vertex']['z'][::reduce_factor],'y':plyfile['vertex']['x'][::reduce_factor],'z':plyfile['vertex']['y'][::reduce_factor]})

# %%
def do_PCA(armadillo):
    from sklearn.decomposition import PCA
    pca = PCA(n_components=2)
    pca.fit(armadillo)
    T = pca.transform(armadillo)
    return T

# %%
fig = plt.figure()
ax  = fig.add_subplot(111, projection='3d')
ax.set_title('Armadillo 3D')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(armadillo.x, armadillo.y, armadillo.z, c='green', marker='.', alpha=0.75)
plt.show()

# %%
def do_RandomizedPCA(armadillo):
    from sklearn.decomposition import RandomizedPCA
    rpca = RandomizedPCA(n_components = 2)
    rpca.fit(armadillo)
    R = rpca.transform(armadillo)
    return R

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_title('Armadillo 3D')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.scatter(armadillo.x, armadillo.y, armadillo.z, c='green', marker='.', alpha=0.75)
plt.show()

# %%
import datetime
t1 = datetime.datetime.now()
pca = do_PCA(armadillo)
time_delta = datetime.datetime.now() - t1
if not pca is None:
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set_title('PCA, build time: ' + str(time_delta))
    ax.scatter(pca[:,0], pca[:,1], c='blue', marker='.', alpha=0.75)
plt.show()

# %%
# Out:
# C:\Users\Santanu\Anaconda2\lib\site-packages\sklearn\utils\deprecation.py:52: DeprecationWarning: Class RandomizedPCA is deprecated; RandomizedPCA was deprecated in 0.18 and will be removed in 0.20. Use PCA(svd_solver='randomized') instead. The new implementation DOES NOT store whiten ``components_``. Apply transform to get them.
#   warnings.warn(msg, category=DeprecationWarning)
